# %%
# Importamos las librerías necesarias
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Para imputación de nulos usando métodos estadísticos avanzados
from sklearn.impute import SimpleImputer 
from sklearn.experimental import enable_iterative_imputer # Necesario para IterativeImputer
from sklearn.impute import IterativeImputer 
from sklearn.impute import KNNImputer

# %%
df_hr = pd.read_csv("hr.csv")
df_hr.head(5)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
# 2  37.0       Yes      Travel_Rarely       1373  Research & Development
# 3  33.0        No  Travel_Frequently       1392  Research & Development
# 4  27.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
def exploracion_basica(df):
    print(f"Las dos primeras filas son:")
    display(df.head(2))
    print("=" * 50)
    print(f"Las dos últimas filas son:")
    display(df.tail(2))
    print("=" * 50)
    print(f"Las dos filas aleatorias son:")
    display(df.sample(2)) 
    print("=" * 50)
    print(f"Información sobre DataFrame:")
    print(df.info())
    print("=" * 50)
    print(f"El dataframe tiene {df.shape[0]} filas y {df.shape[1]} columnas.")
    return df

# %%
df_hr = exploracion_basica(df_hr)
# Out:
# Las dos primeras filas son:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
#
#                 JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      sALES eXECUTIVE               4.0        Single         5993.0
# 1   rESEARCH sCIENTIST               2.0       Married         5130.0
#
# ...

# %%
df_hr.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 944  28.0        No         Non-Travel       1476  Research & Development
# 420  29.0        No      Travel_Rarely        986  Research & Development
# 54   26.0        No      Travel_Rarely       1443                   Sales
# 70   59.0        No  Travel_Frequently       1225                   Sales
# 44   30.0        No  Travel_Frequently        721  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 944                 1          3  Life Sciences              1
# 420                 3          4        Medical              1
# 54                 23          3      Marketing              1
# 70                  1          1  Life Sciences              1
# 44                  1          2        Medical              1
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 944            1315                        3  Female          55
# ...

# %% [markdown]
# **revision para limpieza Maria
#
# - nombre de columnas en minuscula y separado con _
# - attrition es object, no boleano. nes que sigue trabajando en la empresa y si que ya no trabaja allí, no?
# - education: 1 a 4 siendo 1 nivel de estudios mas bajos y 4 mas alto?
# - edad cambiar a int
# - emproyee count no se que es
# - hourly rate es tarifa por hora.
# - job role: cambiar a todo en minusculas
# - bussines travel lo dejaria solo con rarely o con frequantly. como deberiamos de ponerlo todo en minusculas no cuesta nada modificarlo apra que quede mas limpio sin que ponga travel
# - no entiendo bien monthly income y monthly rate
# - departament: poner en minusculas
# - hay varias columnas más que no entiendo bien, mejor lo vemos jutnas, porque hay muchas columnas.
#
# * nulos tenemos en
# YearsWithCurrManager      1326 non-null   float64
# StandardHours             1310 non-null   float64
# OverTime                  1430 non-null   object
# MonthlyIncome             1460 non-null   float6
# JobSatisfaction           1445 non-null   float64
# MaritalStatus             1342 non-null   object
# EducationField            1416 non-null   object
# Department                1445 non-null   object
# BusinessTravel            1357 non-null   object
# Age                       1401 non-null   float64
#
#
# para ver por que la gente se va se me ocurre que tendriamos que ver
# - cuanta gente se ha ido de la empresa
# - si tiene que ver con la antiguedad TotalWorkingYears / YearsAtCompany
# - si tiene que ver con el sueldo DailyRate. ver maximo y minimo y donde se situan, o en las otras columnas de sueldo.
# - si eran hombres o mujeres
# - la edad que tienen
# - si viajaban o no
# - la distancia al trabajo desde casa
# - de que departamento son por si coincide
# - si llevaban mucho tiempo con el mismo responsable o si es el mismo responsable el de todos los que se van
# - si han tenido aumentos de sueldo
# - YearsSinceLastPromotion
# - su grado de sarisfaccion
# - su job involvment
# - si hacen horas extra
# - WorkLifeBalance
# - TrainingTimesLastYea
